# %%
import numpy as np
import pandas as pd

# %%
games = pd.read_csv('jazz_games.csv', index_col=0)
cols_drop = ['Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 8']
games.drop(columns=cols_drop, inplace=True)
games.rename(columns={'Unnamed: 7':'W/L', 'Tm':'Jazz'}, inplace=True)
games.dropna(inplace=True)
games['Date'] = pd.to_datetime(games['Date'])
games
# Out:
#            Date Start (ET)                Opponent W/L   Jazz    Opp     W  \
# G
# 1.0  2023-10-25      9:00p        Sacramento Kings   L  114.0  130.0   0.0
# 2.0  2023-10-27      9:30p    Los Angeles Clippers   W  120.0  118.0   1.0
# 3.0  2023-10-28     10:00p            Phoenix Suns   L  104.0  126.0   1.0
# 4.0  2023-10-30      9:00p          Denver Nuggets   L  102.0  110.0   1.0
# 5.0  2023-11-01      9:00p       Memphis Grizzlies   W  133.0  109.0   2.0
# 6.0  2023-11-02      9:00p           Orlando Magic   L  113.0  115.0   2.0
# 7.0  2023-11-04      8:00p  Minnesota Timberwolves   L   95.0  123.0   2.0
# 8.0  2023-11-06      8:00p           Chicago Bulls   L  113.0  130.0   2.0
# 9.0  2023-11-08      7:00p          Indiana Pacers   L  118.0  134.0   2.0
# 10.0 2023-11-10      8:00p       Memphis Grizzlies   W  127.0  121.0   3.0
# 11.0 2023-11-14      9:00p  Portland Trail Blazers   W  115.0   99.0   4.0
# ...
